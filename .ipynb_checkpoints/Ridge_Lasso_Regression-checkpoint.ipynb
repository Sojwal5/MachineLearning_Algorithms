# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import linear_model
from sklearn.metrics import mean_squared_error ,r2_score

# %%
df=pd.read_csv('melbourne.csv')

# %%
df.head()
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
df.tail()
# Out:
#            Suburb           Address  Rooms Type      Price Method  \
# 34852  Yarraville       13 Burns St      4    h  1480000.0     PI
# 34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 34854  Yarraville    147A Severn St      2    t   705000.0      S
# 34855  Yarraville  12/37 Stephen St      3    h  1140000.0     SP
# 34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 34852            Jas  24/02/2018       6.3    3013.0  ...       1.0  3.0
# 34853        Sweeney  24/02/2018       6.3    3013.0  ...       2.0  1.0
# 34854            Jas  24/02/2018       6.3    3013.0  ...       1.0  2.0
# 34855  hockingstuart  24/02/2018       6.3    3013.0  ...       NaN  NaN
# 34856             RW  24/02/2018       6.3    3013.0  ...       1.0  0.0
#
#        Landsize  BuildingArea  YearBuilt               CouncilArea Lattitude  \
# ...

# %%
df.describe()
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
df.isna()
# Out:
#        Suburb  Address  Rooms   Type  Price  Method  SellerG   Date  Distance  \
# 0       False    False  False  False   True   False    False  False     False
# 1       False    False  False  False  False   False    False  False     False
# 2       False    False  False  False  False   False    False  False     False
# 3       False    False  False  False   True   False    False  False     False
# 4       False    False  False  False  False   False    False  False     False
# ...       ...      ...    ...    ...    ...     ...      ...    ...       ...
# 34852   False    False  False  False  False   False    False  False     False
# 34853   False    False  False  False  False   False    False  False     False
# 34854   False    False  False  False  False   False    False  False     False
# 34855   False    False  False  False  False   False    False  False     False
# 34856   False    False  False  False  False   False    False  False     False
#
# ...

# %%
df.isna().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             7610
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# YearBuilt        19306
# CouncilArea          3
# Lattitude         7976
# Longtitude        7976
# Regionname           3
# Propertycount        3
# dtype: int64

# %%
df.dtypes
# Out:
# Suburb            object
# Address           object
# Rooms              int64
# Type              object
# Price            float64
# Method            object
# SellerG           object
# Date              object
# Distance         float64
# Postcode         float64
# Bedroom2         float64
# Bathroom         float64
# Car              float64
# Landsize         float64
# BuildingArea     float64
# YearBuilt        float64
# CouncilArea       object
# Lattitude        float64
# Longtitude       float64
# Regionname        object
# Propertycount    float64
# dtype: object

# %%
df.nunique()
# Out:
# Suburb             351
# Address          34009
# Rooms               12
# Type                 3
# Price             2871
# Method               9
# SellerG            388
# Date                78
# Distance           215
# Postcode           211
# Bedroom2            15
# Bathroom            11
# Car                 15
# Landsize          1684
# BuildingArea       740
# YearBuilt          160
# CouncilArea         33
# Lattitude        13402
# Longtitude       14524
# Regionname           8
# Propertycount      342
# dtype: int64

# %%
df.shape
# Out:
# (34857, 21)

# %%
col_useful=['Suburb', 'Rooms', 'Type', 'Method', 'SellerG', 'Regionname', 'Propertycount', 
               'Distance', 'CouncilArea', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Price']
df= df[col_useful]

#selecting colums that we want to use and dropping the another columns

# %%
df.shape
# Out:
# (34857, 15)

# %%
df.isna().sum()
# Out:
# Suburb               0
# Rooms                0
# Type                 0
# Method               0
# SellerG              0
# Regionname           3
# Propertycount        3
# Distance             1
# CouncilArea          3
# Bedroom2          8217
# Bathroom          8226
# Car               8728
# Landsize         11810
# BuildingArea     21115
# Price             7610
# dtype: int64

# %%
selected_columns = ['Rooms', 'Distance','Bathroom','Bedroom2' ,'Car', 'Landsize','BuildingArea','Price']
correlation_matrix = df[selected_columns].corr()
print(correlation_matrix)
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap for Selected Features')
plt.show()
#as the corelation between the the features is very low close to 0 not near -1 and 1 so linear regression is not the option 
#polynomial regesiion might help as the releation will be a random curve
#we can also apply overfitting techniques
# Out:
#                  Rooms  Distance  Bathroom  Bedroom2       Car  Landsize  \
# Rooms         1.000000  0.271511  0.611826  0.946755  0.393878  0.037402
# Distance      0.271511  1.000000  0.126201  0.269524  0.241835  0.060862
# Bathroom      0.611826  0.126201  1.000000  0.614892  0.307518  0.036333
# Bedroom2      0.946755  0.269524  0.614892  1.000000  0.388491  0.037019
# Car           0.393878  0.241835  0.307518  0.388491  1.000000  0.037829
# Landsize      0.037402  0.060862  0.036333  0.037019  0.037829  1.000000
# BuildingArea  0.156229  0.076301  0.147558  0.154157  0.104373  0.354530
# Price         0.465238 -0.211384  0.429878  0.430275  0.201803  0.032748
#
#               BuildingArea     Price
# Rooms             0.156229  0.465238
# Distance          0.076301 -0.211384
# Bathroom          0.147558  0.429878
# Bedroom2          0.154157  0.430275
# Car               0.104373  0.201803
# Landsize          0.354530  0.032748
# BuildingArea      1.000000  0.100754
# ...

# %%
#filling null values
#1.Replacing values with 0
#2.Replacing values with mean
#3.dropping the complete row

# Some feature's missing values can be treated as zero (another class for NA values or absence of that feature)
# like 0 for Propertycount, Bedroom2 will refer to other class of NA values
# like 0 for Car feature will mean that there's no car parking feature with house
cols_to_fill_zero = ['Propertycount', 'Distance', 'Bedroom2', 'Bathroom', 'Car']
df[cols_to_fill_zero] = df[cols_to_fill_zero].fillna(0)

# other continuous features can be imputed with mean for faster results since our focus is on Reducing overfitting
# using Lasso and Ridge Regression
df['Landsize'] = df['Landsize'].fillna(df.Landsize.mean())
df['BuildingArea'] = df['BuildingArea'].fillna(df.BuildingArea.mean())

# %%
df.isna().sum()
# Out:
# Suburb              0
# Rooms               0
# Type                0
# Method              0
# SellerG             0
# Regionname          3
# Propertycount       0
# Distance            0
# CouncilArea         3
# Bedroom2            0
# Bathroom            0
# Car                 0
# Landsize            0
# BuildingArea        0
# Price            7610
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# Suburb           0
# Rooms            0
# Type             0
# Method           0
# SellerG          0
# Regionname       0
# Propertycount    0
# Distance         0
# CouncilArea      0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# Price            0
# dtype: int64

# %%
#One hot encoding
df = pd.get_dummies(df, drop_first=True)

# %%
df.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0              False  ...
# 2       79.0000  1035000.0              False  ...
# 4      150.0000  1465000.0              False  ...
# 5      160.2564   850000.0              False  ...
# 6      142.0000  1600000.0              False  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                False                              False
# 2                                False                              False
# ...

# %%
dataset = pd.DataFrame(df)

# Replace True/False with 1/0 for all columns
dataset = dataset.replace({True: 1, False: 0})
# Out:
# /var/folders/t0/ntv84zqn35v6pcxywmhxl1r80000gn/T/ipykernel_15294/3371517545.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   dataset = dataset.replace({True: 1, False: 0})

# %%
dataset.head()
# Out:
#    Rooms  Propertycount  Distance  Bedroom2  Bathroom  Car  Landsize  \
# 1      2         4019.0       2.5       2.0       1.0  1.0     202.0
# 2      2         4019.0       2.5       2.0       1.0  0.0     156.0
# 4      3         4019.0       2.5       3.0       2.0  0.0     134.0
# 5      3         4019.0       2.5       3.0       2.0  1.0      94.0
# 6      4         4019.0       2.5       3.0       1.0  2.0     120.0
#
#    BuildingArea      Price  Suburb_Aberfeldie  ...  \
# 1      160.2564  1480000.0                  0  ...
# 2       79.0000  1035000.0                  0  ...
# 4      150.0000  1465000.0                  0  ...
# 5      160.2564   850000.0                  0  ...
# 6      142.0000  1600000.0                  0  ...
#
#    CouncilArea_Moorabool Shire Council  CouncilArea_Moreland City Council  \
# 1                                    0                                  0
# 2                                    0                                  0
# ...

# %%
dataset.tail()
dataset.dtypes
# Out:
# Rooms                                       int64
# Propertycount                             float64
# Distance                                  float64
# Bedroom2                                  float64
# Bathroom                                  float64
#                                            ...
# CouncilArea_Whitehorse City Council         int64
# CouncilArea_Whittlesea City Council         int64
# CouncilArea_Wyndham City Council            int64
# CouncilArea_Yarra City Council              int64
# CouncilArea_Yarra Ranges Shire Council      int64
# Length: 745, dtype: object

# %%
X = dataset.drop('Price', axis=1)
y = dataset['Price']

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.3, random_state=2)

# %%
lin_model = LinearRegression()

# %%
lin_model.fit(train_X,train_y)
# Out:
# LinearRegression()

# %%
lin_model.score(test_X, test_y)
# Out:
# 0.13853683161729224

# %%
lin_model.score(train_X, train_y)
#It clearly shows that it is overfitting 
#Good accuracy in train but bad in test
# Out:
# 0.6827792395792723

# %%
predict_y=lin_model.predict(test_X)
mse=mean_squared_error(test_y,predict_y)
r2=r2_score(test_y, predict_y)
print(mse)
print(r2)
#r2 score is very less
# Out:
# 342275472103.3883
# 0.13853683161729224

# %%
lasso_reg = linear_model.Lasso(alpha=50, max_iter=100, tol=0.1)
lasso_reg.fit(train_X, train_y)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:678: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.327e+15, tolerance: 7.963e+14
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=50, max_iter=100, tol=0.1)

# %%
lasso_reg.score(test_X, test_y)
# Out:
# 0.6636111369404492

# %%
lasso_reg.score(train_X, train_y)
# Out:
# 0.6766985624766824

# %%
predict_y1=lasso_reg.predict(test_X)

# %%
predict_y=lin_model.predict(test_X)
mse=mean_squared_error(test_y,predict_y1)
r2=r2_score(test_y, predict_y1)
print(mse)
print(r2)
#r2 score is increased by lasso regression
# Out:
# 133653603705.64275
# 0.6636111369404492

# %%
from sklearn.linear_model import Ridge
ridge_reg= Ridge(alpha=50, max_iter=100, tol=0.1)
ridge_reg.fit(train_X, train_y)
# Out:
# Ridge(alpha=50, max_iter=100, tol=0.1)

# %%
ridge_reg.score(test_X, test_y)
# Out:
# 0.6670848945194959

# %%
ridge_reg.score(train_X, train_y)
# Out:
# 0.6622376739684328

# %%
predict_y2=ridge_reg.predict(test_X)
mse=mean_squared_error(test_y,predict_y2)
r2=r2_score(test_y, predict_y2)
print(mse)
print(r2)
#therefor by using ridge and lasso we have increased the performance of the model
# Out:
# 132273414674.95775
# 0.6670848945194959
